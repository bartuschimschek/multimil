# %% [markdown]
# <a href="https://colab.research.google.com/github/bartuschimschek/multimil/blob/new-multimil/paired_integration_cite_seq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Paired integration and query-to-reference mapping
#
# In this tutorial, we demonstrate how to use MultiMIL's integration module for paired integration, i.e. reference building, and mapping on the query onto the built reference. We will use NeurIPS 2021 CITE-seq dataset {cite:p}`Luecken2021-ct`.

# %%
import sys

# if branch is stable, will install via pypi, else will install from source
branch = "latest"
IN_COLAB = "google.colab" in sys.modules

if IN_COLAB and branch == "stable":
    # !pip install multimil[tutorials]
elif IN_COLAB and branch != "stable":
    # !pip install muon
    # !pip install --quiet --upgrade jsonschema
    # !pip install git+https://github.com/bartuschimschek/mmil-refactored
# Out:
# Collecting muon
#   Downloading muon-0.1.6-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from muon) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from muon) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from muon) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from muon) (0.13.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from muon) (3.11.0)
# Collecting anndata (from muon)
#   Downloading anndata-0.10.9-py3-none-any.whl.metadata (6.9 kB)
# Collecting scanpy (from muon)
#   Downloading scanpy-1.10.3-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from muon) (1.5.2)
# Collecting umap-learn (from muon)
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from muon) (0.60.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from muon) (3.20.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from muon) (4.66.5)
# Collecting mudata (from muon)
#   Downloading mudata-0.3.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting array-api-compat!=1.5,>1.4 (from anndata->muon)
#   Downloading array_api_compat-1.9-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata->muon) (1.2.2)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from anndata->muon) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from anndata->muon) (24.1)
# Requirement already satisfied: scipy>1.8 in /usr/local/lib/python3.10/dist-packages (from anndata->muon) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->muon) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->muon) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->muon) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (3.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->muon) (0.43.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy->muon) (1.4.2)
# Collecting legacy-api-wrap>=1.4 (from scanpy->muon)
#   Downloading legacy_api_wrap-1.4-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from scanpy->muon) (3.4.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy->muon) (0.5.6)
# Collecting pynndescent>=0.5 (from scanpy->muon)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting session-info (from scanpy->muon)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy->muon) (0.14.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->muon) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->muon) (1.16.0)
# Collecting stdlib_list (from session-info->scanpy->muon)
#   Downloading stdlib_list-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading muon-0.1.6-py3-none-any.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 20.6 MB/s eta 0:00:00
# Downloading anndata-0.10.9-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 12.8 MB/s eta 0:00:00
# Downloading mudata-0.3.1-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 4.0 MB/s eta 0:00:00
# Downloading scanpy-1.10.3-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 56.7 MB/s eta 0:00:00
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 9.1 MB/s eta 0:00:00
# Downloading array_api_compat-1.9-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 5.1 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4-py3-none-any.whl (15 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 6.2 MB/s eta 0:00:00
# Downloading stdlib_list-0.11.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 9.9 MB/s eta 0:00:00
# Building wheels for collected packages: session-info
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8023 sha256=188ce14757df7364605989e75c98c8f113fb547e752be873a8efe78040f2db3d
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built session-info
# Installing collected packages: array-api-compat, stdlib_list, legacy-api-wrap, session-info, pynndescent, anndata, umap-learn, mudata, scanpy, muon
# Successfully installed anndata-0.10.9 array-api-compat-1.9 legacy-api-wrap-1.4 mudata-0.3.1 muon-0.1.6 pynndescent-0.5.13 scanpy-1.10.3 session-info-1.0.0 stdlib_list-0.11.0 umap-learn-0.5.6
# Collecting git+https://github.com/bartuschimschek/mmil-refactored
#   Cloning https://github.com/bartuschimschek/mmil-refactored to /tmp/pip-req-build-xmjwuuf3
#   Running command git clone --filter=blob:none --quiet https://github.com/bartuschimschek/mmil-refactored /tmp/pip-req-build-xmjwuuf3
#   Resolved https://github.com/bartuschimschek/mmil-refactored to commit 3e419bd6f403d1520dc476078e1c76e99465436a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting anndata==0.10.8 (from multimil==0.2.0)
#   Downloading anndata-0.10.8-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from multimil==0.2.0) (3.7.1)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from multimil==0.2.0) (1.26.4)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.10/dist-packages (from multimil==0.2.0) (1.10.3)
# Collecting scvi-tools==1.1.5 (from multimil==0.2.0)
#   Downloading scvi_tools-1.1.5-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: session-info in /usr/local/lib/python3.10/dist-packages (from multimil==0.2.0) (1.0.0)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /usr/local/lib/python3.10/dist-packages (from anndata==0.10.8->multimil==0.2.0) (1.9)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata==0.10.8->multimil==0.2.0) (1.2.2)
# Requirement already satisfied: h5py>=3.1 in /usr/local/lib/python3.10/dist-packages (from anndata==0.10.8->multimil==0.2.0) (3.11.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from anndata==0.10.8->multimil==0.2.0) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from anndata==0.10.8->multimil==0.2.0) (24.1)
# Requirement already satisfied: pandas!=2.1.0rc0,!=2.1.2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from anndata==0.10.8->multimil==0.2.0) (2.2.2)
# Requirement already satisfied: scipy>1.8 in /usr/local/lib/python3.10/dist-packages (from anndata==0.10.8->multimil==0.2.0) (1.13.1)
# Collecting docrep>=0.3.2 (from scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: flax in /usr/local/lib/python3.10/dist-packages (from scvi-tools==1.1.5->multimil==0.2.0) (0.8.5)
# Requirement already satisfied: jax>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from scvi-tools==1.1.5->multimil==0.2.0) (0.4.33)
# Requirement already satisfied: jaxlib>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from scvi-tools==1.1.5->multimil==0.2.0) (0.4.33)
# Collecting lightning<2.2,>=2.0 (from scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading lightning-2.1.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 5.7 MB/s eta 0:00:00
# Collecting ml-collections>=0.1.1 (from scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mudata>=0.1.2 in /usr/local/lib/python3.10/dist-packages (from scvi-tools==1.1.5->multimil==0.2.0) (0.3.1)
# Collecting numpyro>=0.12.1 (from scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading numpyro-0.15.3-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from scvi-tools==1.1.5->multimil==0.2.0) (0.2.3)
# Collecting pyro-ppl>=1.6.0 (from scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading pyro_ppl-1.9.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from scvi-tools==1.1.5->multimil==0.2.0) (13.9.2)
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from scvi-tools==1.1.5->multimil==0.2.0) (1.5.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from scvi-tools==1.1.5->multimil==0.2.0) (2.5.0+cu121)
# Collecting torchmetrics>=0.11.0 (from scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading torchmetrics-1.5.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: tqdm>=4.56.0 in /usr/local/lib/python3.10/dist-packages (from scvi-tools==1.1.5->multimil==0.2.0) (4.66.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->multimil==0.2.0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->multimil==0.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->multimil==0.2.0) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->multimil==0.2.0) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->multimil==0.2.0) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->multimil==0.2.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->multimil==0.2.0) (2.8.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy->multimil==0.2.0) (1.4.2)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /usr/local/lib/python3.10/dist-packages (from scanpy->multimil==0.2.0) (1.4)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from scanpy->multimil==0.2.0) (3.4.2)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.10/dist-packages (from scanpy->multimil==0.2.0) (0.60.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy->multimil==0.2.0) (0.5.6)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from scanpy->multimil==0.2.0) (0.5.13)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy->multimil==0.2.0) (0.13.2)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy->multimil==0.2.0) (0.14.4)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /usr/local/lib/python3.10/dist-packages (from scanpy->multimil==0.2.0) (0.5.6)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.10/dist-packages (from session-info->multimil==0.2.0) (0.11.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from docrep>=0.3.2->scvi-tools==1.1.5->multimil==0.2.0) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.4->scvi-tools==1.1.5->multimil==0.2.0) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.4->scvi-tools==1.1.5->multimil==0.2.0) (3.4.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.10/dist-packages (from lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (6.0.2)
# Requirement already satisfied: fsspec<2025.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (2024.6.1)
# Collecting lightning-utilities<2.0,>=0.8.0 (from lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading lightning_utilities-0.11.8-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: typing-extensions<6.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (4.12.2)
# Collecting pytorch-lightning (from lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from ml-collections>=0.1.1->scvi-tools==1.1.5->multimil==0.2.0) (1.4.0)
# Collecting contextlib2 (from ml-collections>=0.1.1->scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.56->scanpy->multimil==0.2.0) (0.43.0)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from numpyro>=0.12.1->scvi-tools==1.1.5->multimil==0.2.0) (1.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.8->multimil==0.2.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata==0.10.8->multimil==0.2.0) (2024.2)
# Collecting pyro-api>=0.1.1 (from pyro-ppl>=1.6.0->scvi-tools==1.1.5->multimil==0.2.0)
#   Downloading pyro_api-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->scvi-tools==1.1.5->multimil==0.2.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->scvi-tools==1.1.5->multimil==0.2.0) (2.18.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.2->scvi-tools==1.1.5->multimil==0.2.0) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->scvi-tools==1.1.5->multimil==0.2.0) (3.16.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->scvi-tools==1.1.5->multimil==0.2.0) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->scvi-tools==1.1.5->multimil==0.2.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->scvi-tools==1.1.5->multimil==0.2.0) (1.3.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax->scvi-tools==1.1.5->multimil==0.2.0) (1.1.0)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax->scvi-tools==1.1.5->multimil==0.2.0) (0.6.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax->scvi-tools==1.1.5->multimil==0.2.0) (0.1.66)
# Requirement already satisfied: chex>=0.1.86 in /usr/local/lib/python3.10/dist-packages (from optax->scvi-tools==1.1.5->multimil==0.2.0) (0.1.87)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.10/dist-packages (from optax->scvi-tools==1.1.5->multimil==0.2.0) (1.10.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.86->optax->scvi-tools==1.1.5->multimil==0.2.0) (0.12.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (3.10.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities<2.0,>=0.8.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (75.1.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->scvi-tools==1.1.5->multimil==0.2.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->scvi-tools==1.1.5->multimil==0.2.0) (3.0.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->scvi-tools==1.1.5->multimil==0.2.0) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->scvi-tools==1.1.5->multimil==0.2.0) (3.20.3)
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->scvi-tools==1.1.5->multimil==0.2.0) (4.10.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (4.0.3)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epy]->optax->scvi-tools==1.1.5->multimil==0.2.0) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epy]->optax->scvi-tools==1.1.5->multimil==0.2.0) (3.20.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (3.10)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->scvi-tools==1.1.5->multimil==0.2.0) (0.2.0)
# Downloading anndata-0.10.8-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.4/124.4 kB 12.4 MB/s eta 0:00:00
# Downloading scvi_tools-1.1.5-py3-none-any.whl (387 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.7/387.7 kB 25.6 MB/s eta 0:00:00
# Downloading lightning-2.1.4-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 78.9 MB/s eta 0:00:00
# Downloading numpyro-0.15.3-py3-none-any.whl (351 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 351.1/351.1 kB 34.0 MB/s eta 0:00:00
# Downloading pyro_ppl-1.9.1-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 47.1 MB/s eta 0:00:00
# Downloading torchmetrics-1.5.1-py3-none-any.whl (890 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.6/890.6 kB 60.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.8-py3-none-any.whl (26 kB)
# Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 50.2 MB/s eta 0:00:00
# Building wheels for collected packages: multimil, docrep, ml-collections
#   Building wheel for multimil (pyproject.toml) ... done
#   Created wheel for multimil: filename=multimil-0.2.0-py3-none-any.whl size=52476 sha256=5f18268c2f2cd86d6d6d0220060922f0cb719dd4ebef7f88c4709670ef72ad3a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4lcx3kmr/wheels/8c/5b/ed/0a0694a492d3f9e9f2d7b7601c3d66a7b108b1a19daeef60de
#   Building wheel for docrep (setup.py) ... done
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19877 sha256=23ea4ffa26cd3a14d0e0f3ef7ac9885a38d0666001382838cf77560f6c3a4af7
#   Stored in directory: /root/.cache/pip/wheels/c3/64/48/03c38d8d906159eaa210b3c548fdb590eb3e2a4a5745ae2172
#   Building wheel for ml-collections (setup.py) ... done
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94508 sha256=e3495a1267b31084a3ba8888511baab6297e4044d239eb0f4384fc34debc58bf
#   Stored in directory: /root/.cache/pip/wheels/7b/89/c9/a9b87790789e94aadcfc393c283e3ecd5ab916aed0a31be8fe
# Successfully built multimil docrep ml-collections
# Installing collected packages: pyro-api, lightning-utilities, docrep, contextlib2, ml-collections, torchmetrics, pyro-ppl, anndata, numpyro, pytorch-lightning, lightning, scvi-tools, multimil
#   Attempting uninstall: anndata
#     Found existing installation: anndata 0.10.9
#     Uninstalling anndata-0.10.9:
#       Successfully uninstalled anndata-0.10.9
# Successfully installed anndata-0.10.8 contextlib2-21.6.0 docrep-0.3.2 lightning-2.1.4 lightning-utilities-0.11.8 ml-collections-0.1.1 multimil-0.2.0 numpyro-0.15.3 pyro-api-0.1.2 pyro-ppl-1.9.1 pytorch-lightning-2.4.0 scvi-tools-1.1.5 torchmetrics-1.5.1

# %%
import anndata as ad
import multimil as mtm
import muon
import scanpy as sc
import scvi
import os
import warnings

warnings.filterwarnings("ignore")

# %%
scvi.settings.seed = 0
print("Last run with scvi-tools version:", scvi.__version__)
# Out:
# INFO: Seed set to 0
# INFO:lightning.fabric.utilities.seed:Seed set to 0
# Last run with scvi-tools version: 1.1.5

# %% [markdown]
# ## Data loading
#
# The data contains 90,261 bone marrow mononuclear cells. This CITE-seq (i.e. paired gene expression and surface protein adundance) dataset was generated at 4 different sites introducing some batch effect. After the quality control performed by the authors, the data contains measurements from 13,953 genes and 134 proteins.

# %%
data_path = "GSE194122_openproblems_neurips2021_cite_BMMC_processed.h5ad"

# %%
try:
    adata = sc.read_h5ad(data_path)
    print("File loaded successfully.")
except OSError:
    print("File not found. Attempting to download...")
    exit_code = os.system("wget 'ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE194nnn/GSE194122/suppl/GSE194122_openproblems_neurips2021_cite_BMMC_processed.h5ad.gz'")

    if exit_code == 0:
        print("Download completed successfully. Decompressing the file...")
        decompress_exit_code = os.system("gzip -d GSE194122_openproblems_neurips2021_cite_BMMC_processed.h5ad.gz")

        if decompress_exit_code == 0:
            print("File decompressed successfully. Loading the file...")
            adata = sc.read_h5ad(data_path)
            print("File loaded successfully.")
        else:
            print("File decompression failed.")
    else:
        print("File download failed.")

print(adata)
# Out:
# File loaded successfully.
# AnnData object with n_obs × n_vars = 90261 × 14087
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train'
#     var: 'feature_types', 'gene_id'
#     uns: 'dataset_id', 'genome', 'organism'
#     obsm: 'ADT_X_pca', 'ADT_X_umap', 'ADT_isotype_controls', 'GEX_X_pca', 'GEX_X_umap'
#     layers: 'counts'

# %% [markdown]
# ## Data preparation
#
# We subsample the data to speed up the training.

# %%
sc.pp.subsample(adata, n_obs=20000)
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 20000 × 14087
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train'
#     var: 'feature_types', 'gene_id'
#     uns: 'dataset_id', 'genome', 'organism'
#     obsm: 'ADT_X_pca', 'ADT_X_umap', 'ADT_isotype_controls', 'GEX_X_pca', 'GEX_X_umap'
#     layers: 'counts'

# %% [markdown]
# We split the data into the gene counts and protein counts.

# %%
rna = adata[:, adata.var["feature_types"] == "GEX"].copy()
print(rna)
# Out:
# AnnData object with n_obs × n_vars = 20000 × 13953
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train'
#     var: 'feature_types', 'gene_id'
#     uns: 'dataset_id', 'genome', 'organism'
#     obsm: 'ADT_X_pca', 'ADT_X_umap', 'ADT_isotype_controls', 'GEX_X_pca', 'GEX_X_umap'
#     layers: 'counts'

# %%
adt = adata[:, adata.var["feature_types"] == "ADT"].copy()
print(adt)
# Out:
# AnnData object with n_obs × n_vars = 20000 × 134
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train'
#     var: 'feature_types', 'gene_id'
#     uns: 'dataset_id', 'genome', 'organism'
#     obsm: 'ADT_X_pca', 'ADT_X_umap', 'ADT_isotype_controls', 'GEX_X_pca', 'GEX_X_umap'
#     layers: 'counts'

# %%
# to free memory
del adata

# %% [markdown]
# ## RNA preprocessing
#
# Next, we log-normalize the raw counts and subset the RNA data to 2,000 highly variable genes.

# %%
rna.X = rna.layers["counts"].copy()

# %%
sc.pp.normalize_total(rna, target_sum=1e4)
sc.pp.log1p(rna)

# %%
n_top_genes = 2000
batch_key = "Site"

# %%
sc.pp.highly_variable_genes(rna, n_top_genes=n_top_genes, batch_key=batch_key, subset=True)
print(rna)
# Out:
# AnnData object with n_obs × n_vars = 20000 × 2000
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train'
#     var: 'feature_types', 'gene_id', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'dataset_id', 'genome', 'organism', 'log1p', 'hvg'
#     obsm: 'ADT_X_pca', 'ADT_X_umap', 'ADT_isotype_controls', 'GEX_X_pca', 'GEX_X_umap'
#     layers: 'counts'

# %% [markdown]
# ## ADT preprocessing
#
# We will use centered log-ratio (CLR) normalization for the ADT modality.

# %%
adt.X = adt.layers["counts"].copy()

# %%
muon.prot.pp.clr(adt)
adt.layers["clr"] = adt.X.copy()

# %% [markdown]
# ## Data setup
#
# Next, we create one `AnnData` object from the RNA and ADT objects and specify which layers to use during training.

# %%
adata = mtm.data.organize_multimodal_anndatas(
    adatas=[[rna], [adt]],  # a list of anndata objects per modality, RNA-seq always goes first
    layers=[["counts"], ["clr"]],  # if need to use data from .layers, if None use .X
)
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 20000 × 2134
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'group'
#     var: 'modality'
#     uns: 'modality_lengths'
#     layers: 'counts'

# %% [markdown]
# The data comes from 4 different sites, so we select one of the sites as the query.

# %%
query = adata[adata.obs[batch_key] == "site1"].copy()
adata = adata[adata.obs[batch_key] != "site1"].copy()
print(adata, query)
# Out:
# AnnData object with n_obs × n_vars = 16433 × 2134
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'group'
#     var: 'modality'
#     uns: 'modality_lengths'
#     layers: 'counts' AnnData object with n_obs × n_vars = 3567 × 2134
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'group'
#     var: 'modality'
#     uns: 'modality_lengths'
#     layers: 'counts'

# %% [markdown]
# We specify which covariates we want to integrate out during training, i.e. if there is batch effect in the data we want to correct, which covariate should be used as the batch covariate. Please refer to the API if you need to specify multiple covariates or continuous covariates.

# %%
rna_indices_end = rna.shape[1]

# %%
mtm.model.MultiVAE.setup_anndata(
    adata,
    categorical_covariate_keys=[batch_key],
    rna_indices_end=rna_indices_end,
)

# %% [markdown]
# ## Model setup and training
#
# In the next step, we initialize the model. We need to pass which `adata` the model will be trained on and which losses should be used for each of the modalities. Since we use raw counts for RNA, we will use negative binomial loss here (`'nb'`), and MSE (`'mse'`) for the normalized ADT counts.

# %%
vae = mtm.model.MultiVAE(
    adata,
    losses=["nb", "mse"],
)

# %% [markdown]
# Now, we finally are set and can train the model and visualize the losses.

# %%
vae.train() # The default value for max_epochs is 200. We can set max_epochs like this: vae.train(max_epochs=50).
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 200/200: 100%|██████████| 200/200 [04:24<00:00,  1.15s/it, v_num=1, train_loss_step=496, train_loss_epoch=508]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 200/200: 100%|██████████| 200/200 [04:24<00:00,  1.32s/it, v_num=1, train_loss_step=496, train_loss_epoch=508]

# %%
vae.plot_losses()

# %% [markdown]
# ## Visualizing the latent space
#
# Next, we retrieve the learned latent representation; it is automatically saved in `adata.obsm['X_multiMIL']`.

# %%
vae.get_model_output()
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 16433 × 2134
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'group', 'size_factors', '_scvi_batch'
#     var: 'modality'
#     uns: 'modality_lengths', '_scvi_uuid', '_scvi_manager_uuid'
#     obsm: '_scvi_extra_categorical_covs', 'X_multiMIL'
#     layers: 'counts'

# %% [markdown]
# Finally, we visualize the latent space.

# %%
sc.pp.neighbors(adata, use_rep="X_multiMIL")
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=["cell_type", "Site"], frameon=False, ncols=1)

# %% [markdown]
# ## Preparing the query
#
# MultiMIL is equipped with scArches approach {cite:p}`Lotfollahi2022-jw` to map new query data onto existing references.
#
# First, we need to update the model architecture to add weights for the new query batches.

# %%
new_vae = mtm.model.MultiVAE.load_query_data(query, reference_model=vae)

# %% [markdown]
# Next, we fine-tune the newly added weights to optimize the reconstruction of the query data. We set `weight_decay` to zero to make sure that the rest of the weights in the model will not be changed.

# %%
new_vae.train(
    weight_decay=0,
)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 200/200: 100%|██████████| 200/200 [00:56<00:00,  3.88it/s, v_num=1, train_loss_step=715, train_loss_epoch=737]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 200/200: 100%|██████████| 200/200 [00:56<00:00,  3.53it/s, v_num=1, train_loss_step=715, train_loss_epoch=737]

# %% [markdown]
# Now, we obtain the latent representation of the query and visualize both the reference and the query together.

# %%
new_vae.get_model_output(query)
print(query)
# Out:
# AnnData object with n_obs × n_vars = 3567 × 2134
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'group', 'size_factors', '_scvi_batch'
#     var: 'modality'
#     uns: 'modality_lengths', '_scvi_uuid', '_scvi_manager_uuid'
#     obsm: '_scvi_extra_categorical_covs', 'X_multiMIL'
#     layers: 'counts'

# %%
adata.obs["reference"] = "reference"
query.obs["reference"] = "query"
adata_both = ad.concat([adata, query])
print(adata_both)
# Out:
# AnnData object with n_obs × n_vars = 20000 × 2134
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'group', 'size_factors', '_scvi_batch', 'reference'
#     obsm: '_scvi_extra_categorical_covs', 'X_multiMIL'
#     layers: 'counts'

# %%
sc.pp.neighbors(adata_both, use_rep="X_multiMIL")
sc.tl.umap(adata_both)

# %%
sc.pl.umap(adata_both, color=["cell_type", "Site", "reference"], ncols=1, frameon=False)
